# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
mall_data = pd.read_csv("https://raw.githubusercontent.com/tirthajyoti/Machine-Learning-with-Python/master/Datasets/Mall_Customers.csv")

# %%
mall_df = mall_data
mall_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# x = mall_df.iloc[[2],[3,4]].values
x = mall_df.iloc[:,[3,4]].values
print(x)
# Out:
# [[ 15  39]
#  [ 15  81]
#  [ 16   6]
#  [ 16  77]
#  [ 17  40]
#  [ 17  76]
#  [ 18   6]
#  [ 18  94]
#  [ 19   3]
#  [ 19  72]
#  [ 19  14]
#  [ 19  99]
#  [ 20  15]
#  [ 20  77]
#  [ 20  13]
#  [ 20  79]
#  [ 21  35]
#  [ 21  66]
#  [ 23  29]
#  [ 23  98]
#  [ 24  35]
#  [ 24  73]
#  [ 25   5]
#  [ 25  73]
#  [ 28  14]
#  [ 28  82]
#  [ 28  32]
#  [ 28  61]
#  [ 29  31]
#  [ 29  87]
#  [ 30   4]
#  [ 30  73]
#  [ 33   4]
#  [ 33  92]
#  [ 33  14]
#  [ 33  81]
#  [ 34  17]
#  [ 34  73]
#  [ 37  26]
#  [ 37  75]
#  [ 38  35]
#  [ 38  92]
#  [ 39  36]
#  [ 39  61]
#  [ 39  28]
#  [ 39  65]
#  [ 40  55]
#  [ 40  47]
#  [ 40  42]
#  [ 40  42]
#  [ 42  52]
#  [ 42  60]
#  [ 43  54]
#  [ 43  60]
#  [ 43  45]
#  [ 43  41]
#  [ 44  50]
#  [ 44  46]
#  [ 46  51]
#  [ 46  46]
#  [ 46  56]
#  [ 46  55]
#  [ 47  52]
#  [ 47  59]
#  [ 48  51]
#  [ 48  59]
#  [ 48  50]
#  [ 48  48]
#  [ 48  59]
#  [ 48  47]
#  [ 49  55]
#  [ 49  42]
#  [ 50  49]
#  [ 50  56]
#  [ 54  47]
#  [ 54  54]
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
plt.figure(figsize=(12,9))
# sns.scatterplot(x=x_scaled[:,0], y=x_scaled[:,1])
plt.scatter(x_scaled[:,0], x_scaled[:,1], c="blue",)
plt.title("Customer Segments (Unscaled Data distribution)")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.grid()
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5,random_state=42)
kmeans.fit(x_scaled)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
mall_df['Cluster'] = kmeans.fit_predict(x_scaled)
# mall_df['Cluster'].reset_index()
mall_df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        4
# 1        2
# 2        4
# 3        2
# 4        4

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.20091257, -0.02645617],
#        [ 0.99158305,  1.23950275],
#        [-1.32954532,  1.13217788],
#        [ 1.05500302, -1.28443907],
#        [-1.30751869, -1.13696536]])

# %%
# k means grouping visualization

plt.figure(figsize=(12,9))
colors = ['red', 'blue', 'green', 'cyan', 'magenta']
for i in range(5):
    # plt.scatter(x_scaled[mall_df['Cluster'] == i, 0], x_scaled[mall_df['Cluster'] == i, 1], s=100, c=colors[i], label='Cluster '+str(i+1))
    plt.scatter(x[mall_df['Cluster'] == i, 0], x[mall_df['Cluster'] == i, 1],c=colors[i], label='Cluster '+str(i+1))

plt.title("Customer Segments (Scaled Data Distribution)")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.legend()
plt.grid()
plt.show()

# %%
mall_df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        4
# 1        2
# 2        4
# 3        2
# 4        4
