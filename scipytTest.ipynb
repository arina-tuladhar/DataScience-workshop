# %% [markdown]
# T test example for sales data

# %%
from scipy import stats
import numpy as np
#group A: sales without a discount(per day data)
group_a = [200,210,190,205,195]
#group B: sales with a discount
group_b = [250,240,260,230,255]

t_stat, p_val = stats.ttest_ind(group_a, group_b)
print(f"p_value: {p_val:.4f}")
if p_val<0.05:
    print("The discount significantly increased sales!")
else:
    print("The difference might just be luck.")
# Out:
# p_value: 0.0001
# The discount significantly increased sales!

# %%
#T test for teaching method
from scipy import stats
import numpy as np
#group A: scores of students using Traditional books
group_a = [65,70,62,68,72]
#group A: scores of students using interactive AI Tools
group_b = [85,88,90,82,87]

t_stat, p_val = stats.ttest_ind(group_a, group_b)
print(f"p_value: {p_val:.4f}")
if p_val<0.05:
    print("AI tools significantly improved learning outcomes!")
else:
    print("No significant difference between teaching methdos.")
# Out:
# p_value: 0.0000
# AI tools significantly improved learning outcomes!
